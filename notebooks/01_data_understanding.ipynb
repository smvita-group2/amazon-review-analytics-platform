# %%
import os
import sys

project_root = os.path.abspath("..")
sys.path.insert(0, project_root)

# %%
from src.common.spark_session import create_spark_session

spark = create_spark_session()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/18 03:22:29 WARN Utils: Your hostname, Shreyashs-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.0.0.2 instead (on interface en0)
# 26/07/18 03:22:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /Users/shreyash/Developer/Projects/amazon-review-v2/amazon-review-analytics-platform/.venv/lib/python3.11/site-packages/pyspark/testing/utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 26/07/18 03:22:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/07/18 03:22:31 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# ============================================================
# Amazon Review Analytics Platform
# Notebook 01 : Data Understanding
# Author : Shreyash Dongare
# ============================================================

# %%
from pyspark.sql import functions as F

from src.common.spark_session import create_spark_session

# %%
spark = create_spark_session()

print(f"Spark Version : {spark.version}")
# Out:
# Spark Version : 4.2.0
